# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# set the parameters 
num_samples = 1000
sample_size = 30
distribution_range = (0,1)

# genterate samples from uniform distribution 
sample = np.random.uniform(distribution_range[0],distribution_range[1],(num_samples,sample_size))

# calculate the mean of each sample 
sample_mean = np.mean(sample,axis=1)
# plot the histogram of sample means
plt.hist(sample_mean,bins=30)
plt.show()

# %%
sample.shape
# Out:
# (1000, 30)

# %%
sample_mean.shape
# Out:
# (1000,)

# %%
import seaborn as sns
#proper normal distribution 
sns.distplot(sample_mean)
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/296039706.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# <Axes: ylabel='Density'>

# %% [markdown]
# # Proving that the if the mean of the population is m and variance is s^2 then the mean for the normal distribution will be m and variance will be s^2/n where n is the number of samples

# %%
# set the parameters 
num_samples = 10000
sample_size = 50

#gamma distribution parameters
gamma_shape = 2
gamma_scale = 1

#calculate the theoritical mean and variance
theoritical_mean = gamma_shape * gamma_scale
theoritical_variance = gamma_shape * (gamma_scale**2)

# generate the samples from gamma distribution
sample1 = np.random.gamma(shape=gamma_shape,scale=gamma_scale, size=(num_samples, sample_size))

# calculate the mean and variance of each sample
sample_mean1 = np.mean(sample1, axis=1)



# plot the histogram of sample means
plt.hist(sample_mean, bins=30)
plt.show()

# %%
#calculate the empirical mean and variance
empirical_mean = np.mean(sample_mean1)
empirical_variance = np.var(sample_mean1)

# print the results
print("Theoritical Mean:", theoritical_mean)
print("Theoritical Variance:", theoritical_variance)
print("Empirical Mean:", empirical_mean)
print("Empirical Variance:", empirical_variance)
# Out:
# Theoritical Mean: 2
# Theoritical Variance: 2
# Empirical Mean: 1.998993072803654
# Empirical Variance: 0.03965871066506425

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
df = pd.concat([train_df.drop(columns=['Survived']),test_df])

# %%
import seaborn as sns

# %%
sns.distplot(df['Fare'])
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/3425841524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sample2 = []
for i in range(100):
    sample2.append(df['Fare'].dropna().sample(50).values.tolist())

# %%
sample2 = np.array(sample2)
sample2_mean = sample2.mean(axis=1)

# %%
sns.distplot(sample2_mean)
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/3522535270.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample2_mean)
# <Axes: ylabel='Density'>

# %%
sample2_mean.mean()
# Out:
# 33.32054464

# %%
df['Fare'].mean()
# Out:
# 33.29547928134557

# %%
sample2_mean.std()/np.sqrt(50)
# Out:
# 0.9456928254454288

# %%
lower_limit = sample2_mean.mean() - 2*sample2_mean.std()/np.sqrt(50) # since we are taking 2 std
upper_limit = sample2_mean.mean() + 2*sample2_mean.std()/np.sqrt(50)

# %%
print(lower_limit,upper_limit)
# Out:
# 31.429158989109144 35.21193029089086

# %%
sample_age = []

for i in range(100):
    sample_age.append(df['Age'].dropna().sample(50).values.tolist())
sample_age = np.array(sample_age)

# %%
sample_age_mean = sample_age.mean(axis=1)

# %%
sns.distplot(sample_age_mean)
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/1206281066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_age_mean)
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['Age'])
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
lower_limit_age = sample_age_mean.mean() - 2*sample_age_mean.std()/np.sqrt(50) # since we are taking 2 std
upper_limit_age = sample_age_mean.mean() + 2*sample_age_mean.std()/np.sqrt(50)

# %%
print(lower_limit_age,upper_limit_age)
# Out:
# 29.57422005608226 30.72729194391774

# %%
df['Age'].mean()
# Out:
# 29.881137667304014

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# Out:
# <bound method DataFrame.value_counts of      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
sns.distplot(df['Fare'])
# Out:
# /var/folders/gm/nbsrp6ks1gnb1c4z3v9rvb4r0000gn/T/ipykernel_70793/3425841524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sampleX= []
stds = []
for i in range(10):
    x = df['Fare'].dropna().sample(50).values
    stds.append(x.std())
    sampleX.append(x.tolist())

# %%
sampleX = np.array(sampleX)

# %%
sampleX_mean = sampleX.mean(axis=1)

# %%
sample_std = np.mean(stds)

# %%
lower_limitX = sampleX_mean.mean() - 2.042*(sample_std/np.sqrt(50)) # since we are taking 2 std
upper_limitX = sampleX_mean.mean() + 2.042*(sample_std/np.sqrt(50))
print(lower_limitX,upper_limitX)
# Out:
# 19.29290775681713 48.13362584318287
